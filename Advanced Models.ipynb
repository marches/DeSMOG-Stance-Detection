# %%
import pandas as pd

# %%
data = pd.read_table("./GWSD.tsv")

# %%
data.head(10)
# Out:
#    Unnamed: 0  round  batch sent_id  \
# 0           0      1      0      s0
# 1           1      1      0      s1
# 2           2      1      0      s2
# 3           3      1      0      s3
# 4           4      1      0      s4
# 5           5      1      0      t0
# 6           6      1      0      t1
# 7           7      1      0     t10
# 8           8      1      0     t11
# 9           9      1      0     t12
#
#                                             sentence   worker_0   worker_1  \
# 0                          Global warming is a hoax.  disagrees  disagrees
# 1  Alarming levels of sea level rise are predicte...    neutral    neutral
# 2  Over the past several years, the United States...    neutral    neutral
# 3  Global warming is happening and it will be dan...     agrees     agrees
# 4                            Some icebergs are cute.    neutral    neutral
# 5  Warmer-than-normal sea surface temperatures ar...    neutral    neutral
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'guid', 'sent_no', 'quote_no',
#        'quote_text', 'coref', 'quote_stems', 'quote_stems_coref',
#        'quote_stem_list', 'quote_stem_list_coref'],
#       dtype='object')
